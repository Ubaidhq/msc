# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("48_Industry_Portfolios_daily.CSV")
dates = pd.to_datetime(df.iloc[:, 0], format='%Y%m%d', errors='coerce')
df.iloc[:, 0] = dates
# Out:
# C:\Users\Ubaid\miniconda3\envs\msc\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,11,15,20,26,27,33,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df=df.rename(columns = {'Unnamed: 0':'Date'})

# %%
df.dropna(axis=0, inplace=True)
df.drop('Date', axis=1, inplace=True)

# %%
from sklearn.cluster import KMeans # Our clustering algorithm
from sklearn.decomposition import PCA # Needed for dimension reduction
from sklearn.preprocessing import StandardScaler

# %%
correlation = df.corr()
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_e8f2c_row0_col0,#T_e8f2c_row1_col1,#T_e8f2c_row2_col2,#T_e8f2c_row3_col3,#T_e8f2c_row4_col4,#T_e8f2c_row5_col5,#T_e8f2c_row6_col6,#T_e8f2c_row7_col7,#T_e8f2c_row8_col8,#T_e8f2c_row9_col9,#T_e8f2c_row10_col10,#T_e8f2c_row11_col11,#T_e8f2c_row12_col12,#T_e8f2c_row13_col13,#T_e8f2c_row14_col14,#T_e8f2c_row15_col15,#T_e8f2c_row16_col16,#T_e8f2c_row17_col17,#T_e8f2c_row18_col18,#T_e8f2c_row19_col19,#T_e8f2c_row20_col20,#T_e8f2c_row21_col21,#T_e8f2c_row22_col22,#T_e8f2c_row23_col23,#T_e8f2c_row24_col24,#T_e8f2c_row25_col25,#T_e8f2c_row26_col26,#T_e8f2c_row27_col27,#T_e8f2c_row28_col28,#T_e8f2c_row29_col29,#T_e8f2c_row30_col30,#T_e8f2c_row31_col31,#T_e8f2c_row32_col32,#T_e8f2c_row33_col33,#T_e8f2c_row34_col34,#T_e8f2c_row35_col35,#T_e8f2c_row36_col36,#T_e8f2c_row37_col37,#T_e8f2c_row38_col38,#T_e8f2c_row39_col39{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e8f2c_row0_col1,#T_e8f2c_row5_col9,#T_e8f2c_row6_col17,#T_e8f2c_row6_col33,#T_e8f2c_row8_col28,#T_e8f2c_row8_col32,#T_e8f2c_row21_col5,#T_e8f2c_row24_col28,#T_e8f2c_row27_col0,#T_e8f2c_row27_col3,#T_e8f2c_row27_col22,#T_e8f2c_row35_col6,#T_e8f2c_row36_col37{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_e8f2c_row0_col2,#T_e8f2c_row2_col27,#T_e8f2c_row6_col4,#T_e8f2c_row9_col2,#T_e8f2c_row11_col26,#T_e8f2c_row32_col14,#T_e8f2c_row32_col21,#T_e8f2c_row32_col35,#T_e8f2c_row37_col11,#T_e8f2c_row37_col20,#T_e8f2c_row37_col35,#T_e8f2c_row39_col6{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_e8f2c_row0_col3,#T_e8f2c_row2_col6,#T_e8f2c_row2_col28,#T_e8f2c_row3_col19,#T_e8f2c_row4_col1,#T_e8f2c_row4_col5,#T_e8f2c_row14_col9,#T_e8f2c_row21_col4,#T_e8f2c_row21_col6,#T_e8f2c_row22_col36,#T_e8f2c_row37_col21,#T_e8f2c_row39_col22{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_e8f2c_row0_col4,#T_e8f2c_row3_col15,#T_e8f2c_row9_col38,#T_e8f2c_row22_col9,#T_e8f2c_row37_col39{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T

#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_e8f2c_row0_col30,#T_e8f2c_row6_col8,#T_e8f2c_row6_col10,#T_e8f2c_row7_col22,#T_e8f2c_row9_col7,#T_e8f2c_row15_col26,#T_e8f2c_row20_col9,#T_e8f2c_row21_col25,#T_e8f2c_row29_col26,#T_e8f2c_row32_col15,#T_e8f2c_row32_col33,#T_e8f2c_row37_col12{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_e8f2c_row0_col32,#T_e8f2c_row9_col39,#T_e8f2c_row22_col34{
#             background-color:  #53

# %%
pca = PCA(n_components=48)
print(df)
principalComponents = pca.fit_transform(df)
# Out:
#        Agric  Food  Soda   Beer   Smoke  Toys   Fun    Books  Hshld  Clths  \
# 0       0.56  -0.07   NaN  -1.39   0.00  -1.44   0.62  -1.27  -0.90   0.12
# 1       0.29   0.06   NaN   0.78   0.70   1.46   0.03   0.00  -0.34  -0.35
# 2      -0.33   0.18   NaN  -1.74   0.50  -0.96  -0.06   4.27  -1.20   0.41
# 3       3.57  -0.15   NaN  -1.73  -0.12  -0.49  -0.06  -4.10  -0.22   0.16
# 4       0.30   1.12   NaN  -0.15   0.30  -0.49   0.24   0.00  -0.01   0.79
# ...      ...    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 24094  -0.19  -0.16 -0.62  -0.59  -1.06   0.72  -0.92  -0.34  -0.27   1.12
# 24095   0.01  -0.20  0.45   0.26   1.30   0.37   0.17   0.18   0.40   1.45
# 24096   0.09   0.12 -0.32  -0.36  -1.10  -1.20   1.04  -0.54  -0.59  -0.57
# 24097  -0.35  -1.88 -0.39  -0.44  -1.24   1.38  -0.79  -0.56  -1.03  -1.14
# 24098   0.00   2.41  0.56   1.26   0.08  -3.98   1.05  -0.22   0.53  -1.34
#
#        ... Boxes  Trans  Whlsl  Rtail Meals  Banks  Insur  RlEst  Fin   Other
# 0      ... -0.93   0.15   2.77  -0.02  0.27   0.59   0.47   0.81   0.69 -1.66
# 1      ...  1.07   0.06   0.00   0.01 -0.10   1.04  -0.03  -0.61  -0.45  3.09
# 2      ...  0.73  -0.19   0.77  -0.22 -0.67   0.45   0.31  -0.72   0.04  1.41
# 3      ...  2.22   0.18  -3.21  -0.57 -0.70  -1.09   0.21   0.07  -0.40  0.62
# 4      ... -0.39   0.46  -1.10  -0.38  0.33   0.99  -0.88  -0.36  -0.93  0.98
# ...    ...   ...    ...    ...    ...   ...    ...    ...    ...    ...   ...
# 24094  ... -0.56  -1.73  -0.45   0.00 -0.68  -0.20  -0.02  -1.24  -0.81 -0.79
# 24095  ...  0.29   0.91  -0.48   0.03  1.08   0.76   0.99   1.06   0.70  0.04
# 24096  ... -0.09  -0.26  -1.46   2.79  0.19   0.29   0.32  -0.04  -0.12 -0.55
# 24097  ... -0.85  -1.17  -0.36  -0.45  0.20  -0.58  -0.58  -0.68  -0.81 -0.58
# 24098  ...  0.95  -0.45   0.97   0.01  0.08  -0.14   0.01   0.91   0.09 -0.50
#
# [24099 rows x 48 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-ed895cdfc4e7> in <module>
#       2 df.drop('Date', axis=1, inplace=True)
#       3 print(df)
# ----> 4 principalComponents = pca.fit_transform(df)
#
# ~\miniconda3\envs\msc\lib\site-packages\sklearn\decomposition\_pca.py in fit_transform(self, X, y)
#     374         C-ordered array, use 'np.ascontiguousarray'.
#     375         """
# --> 376         U, S, Vt = self._fit(X)
#     377         U = U[:, :self.n_components_]
#     378
#
# ~\miniconda3\envs\msc\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     395                             'TruncatedSVD for a possible alternative.')
#     396
# --> 397         X = self._validate_data(X, dtype=[np.float64, np.float32],
#     398                                 ensure_2d=True, copy=self.copy)
#     399
#
# ~\miniconda3\envs\msc\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\miniconda3\envs\msc\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\miniconda3\envs\msc\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# ~\miniconda3\envs\msc\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

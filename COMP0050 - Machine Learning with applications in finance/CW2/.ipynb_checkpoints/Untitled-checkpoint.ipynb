# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df = pd.read_csv("48_Industry_Portfolios_daily.CSV")
dates = pd.to_datetime(df.iloc[:, 0], format='%Y%m%d', errors='coerce')
df.iloc[:, 0] = dates
# Out:
# C:\Users\Ubaid\miniconda3\envs\msc\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,11,15,20,26,27,33,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df=df.rename(columns = {'Unnamed: 0':'Date'})
df = df[df['Date'] > '2000-01-01']

# %%
df.replace(' NaN', np.nan, inplace=True)

# %%
df.dropna(inplace=True)
df.drop('Date', axis=1, inplace=True)
df
# Out:
#        Agric  Food  Soda   Beer   Smoke  Toys   Fun    Books  Hshld  Clths  \
# 19612  -3.41  -2.37 -0.52  -1.16   1.67  -0.57  -1.65  -2.55  -2.75  -2.37
# 19613  -2.68  -2.27 -2.19  -1.11   0.64  -3.03   0.40  -2.75  -2.10  -3.59
# 19614   3.00  -0.03  1.12   1.33  -0.41  -2.17  -0.19  -2.20  -1.42   1.92
# 19615   0.24   0.99  3.69   1.29  -1.28   0.03  -1.87   0.27   2.69  -0.44
# 19616   2.77   1.18  1.49   5.25   2.75   0.71   0.81  -1.27   5.40   1.09
# ...      ...    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 24094  -0.19  -0.16 -0.62  -0.59  -1.06   0.72  -0.92  -0.34  -0.27   1.12
# 24095   0.01  -0.20  0.45   0.26   1.30   0.37   0.17   0.18   0.40   1.45
# 24096   0.09   0.12 -0.32  -0.36  -1.10  -1.20   1.04  -0.54  -0.59  -0.57
# 24097  -0.35  -1.88 -0.39  -0.44  -1.24   1.38  -0.79  -0.56  -1.03  -1.14
# 24098   0.00   2.41  0.56   1.26   0.08  -3.98   1.05  -0.22   0.53  -1.34
#
#        ... Boxes  Trans  Whlsl  Rtail Meals  Banks  Insur  RlEst  Fin   Other
# 19612  ... -2.16  -0.85  -1.33  -2.57 -2.12  -4.60  -3.07  -2.11  -4.11 -0.72
# 19613  ... -1.59  -2.57  -2.59  -3.46 -1.82  -3.85  -3.61  -1.58  -4.55 -2.00
# 19614  ...  1.18   0.31   2.27  -0.97  1.19  -0.38   0.32   1.07  -2.27  0.06
# 19615  ...  1.87   3.06   3.72  -0.14 -0.73   4.00   2.38  -0.56   1.92 -0.30
# 19616  ... -1.05   1.12   2.71   4.79  1.50   1.18   4.27   1.64   1.43  0.59
# ...    ...   ...    ...    ...    ...   ...    ...    ...    ...    ...   ...
# 24094  ... -0.56  -1.73  -0.45   0.00 -0.68  -0.20  -0.02  -1.24  -0.81 -0.79
# 24095  ...  0.29   0.91  -0.48   0.03  1.08   0.76   0.99   1.06   0.70  0.04
# 24096  ... -0.09  -0.26  -1.46   2.79  0.19   0.29   0.32  -0.04  -0.12 -0.55
# 24097  ... -0.85  -1.17  -0.36  -0.45  0.20  -0.58  -0.58  -0.68  -0.81 -0.58
# 24098  ...  0.95  -0.45   0.97   0.01  0.08  -0.14   0.01   0.91   0.09 -0.50
#
# [4487 rows x 48 columns]

# %%
from sklearn.cluster import KMeans # Our clustering algorithm
from sklearn.decomposition import PCA # Needed for dimension reduction
from sklearn.preprocessing import StandardScaler

# %%
correlation = df.corr()
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T

# Out:
#             0         1         2         3         4         5         6   \
# 0    -2.068781 -2.452935 -0.403501 -1.097657  1.089907 -0.394867 -0.857583
# 1    -1.632565 -2.351207 -1.575781 -1.051902  0.382876 -2.008232  0.172097
# 2     1.761550 -0.072493  0.747721  1.180942 -0.337883 -1.444210 -0.124250
# 3     0.112297  0.965135  2.551770  1.144338 -0.935083 -0.001364 -0.968085
# 4     1.624112  1.158419  1.007448  4.768132  1.831259  0.444607  0.378033
# ...        ...       ...       ...       ...       ...       ...       ...
# 4482 -0.144652 -0.204740 -0.473697 -0.576050 -0.784067  0.451165 -0.490916
# 4483 -0.025141 -0.245431  0.277405  0.201785  0.835925  0.221622  0.056572
# 4484  0.022664  0.080099 -0.263108 -0.365577 -0.811524 -0.808046  0.493558
# 4485 -0.240261 -1.954466 -0.312245 -0.438785 -0.907625  0.884019 -0.425619
# 4486 -0.031116  2.409677  0.354621  1.116885 -0.001528 -2.631279  0.498581
#
#             7         8         9   ...        38        39        40  \
# 0    -1.675642 -2.549451 -1.546250  ... -1.503139 -0.624217 -1.130751
# 1    -1.806264 -1.952918 -2.324409  ... -1.115524 -1.819014 -2.173078
# 2    -1.447054 -1.328852  1.190064  ...  0.768150  0.181576  1.847328
# 3     0.166126  2.443073 -0.315228  ...  1.237368  2.091863  3.046832
# 4    -0.839662  4.930158  0.660661  ... -0.748310  0.744243  2.211315
# ...        ...       ...       ...  ...       ...       ...       ...
# 4482 -0.232271 -0.273447  0.679796  ... -0.415097 -1.235508 -0.402776
# 4483  0.107346  0.341441  0.890282  ...  0.162926  0.598366 -0.427593
# 4484 -0.362893 -0.567125 -0.398146  ... -0.095484 -0.214374 -1.238292
# 4485 -0.375955 -0.970933 -0.761712  ... -0.612304 -0.846505 -0.328324
# 4486 -0.153898  0.460747 -0.889280  ...  0.611744 -0.346357  0.771911
#
#             41        42        43        44        45        46        47
# 0    -1.977123 -1.741510 -2.402509 -2.097644 -1.124929 -2.049334 -0.496190
# 1    -2.652467 -1.501019 -2.013972 -2.461491 -0.848394 -2.266476 -1.352568
# 2    -0.763021  0.911902 -0.216338  0.186502  0.534279 -1.141283  0.025666
# 3    -0.133206 -0.627237  2.052722  1.574508 -0.316195  0.926505 -0.215191
# 4     3.607745  1.160409  0.591821  2.847970  0.831684  0.684687  0.380260
# ...        ...       ...       ...       ...       ...       ...       ...
# 4482 -0.026972 -0.587155 -0.123089 -0.042587 -0.670995 -0.420765 -0.543023
# 4483 -0.004208  0.823722  0.374240  0.637941  0.529061  0.324428  0.012285
# 4484  2.090118  0.110267  0.130756  0.186502 -0.044878 -0.080247 -0.382452
# 4485 -0.368438  0.118284 -0.319948 -0.419909 -0.378807 -0.420765 -0.402523
# 4486 -0.019384  0.022087 -0.092006 -0.022373  0.450797  0.023390 -0.349000
#
# [4487 rows x 48 columns]

# %%
pca = PCA(n_components=48)
principalComponents = pca.fit_transform(df_std)
print(principalComponents)
# Out:
# [[ -8.37734611   3.25733454  -0.57151155 ...   0.92794422  -0.37706609
#     0.92385966]
#  [-11.24223796  -1.22890733   1.46688498 ...   0.18394729   0.05139054
#    -0.1091094 ]
#  [  3.29914117  -2.83040692   2.23549218 ...  -0.17080871  -0.38391733
#     0.4604771 ]
#  ...
#  [  0.32332688   0.7533125   -0.70206521 ...   1.46708858  -0.55866701
#     0.22392124]
#  [ -2.97253794   1.30358137   0.74412562 ...   0.68028425  -0.08171734
#     0.51074626]
#  [  0.93082984  -1.16884306   0.1560249  ...  -0.14071852   0.27084744
#     0.21038277]]

# %%
plt.figure(figsize = (10,8))
plt.plot(range(1,49), pca.explained_variance_ratio_.cumsum(), marker='o')
plt.xticks(range(1,49), rotation = 90 )
plt.title('Explained Variance by Principle Components')
plt.xlabel('Number of principle components')
plt.ylabel('Cumulative Explained Variance')
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
pca.components_.shape
# Out:
# (48, 48)

# %% [markdown]
# # Bootstrapping

# %%
from sklearn.utils import resample
def bootstrap(data):
    # prepare bootstrap sample
    boot = resample(data, replace=True, n_samples=len(data))
    return boot

# %%
df_bs = bootstrap(df)
df_bs = scaler.fit_transform(df_bs)

# %% [markdown]
# # PCA with K-means clustering

# %%
# %matplotlib inline
pca = PCA(n_components=48)
principalComponents = pca.fit_transform(df_bs)
coefficients = pd.DataFrame(pca.components_)
PCA_components = pd.DataFrame(principalComponents)
plt.scatter(coefficients.iloc[0,:], coefficients.iloc[1,:], alpha=.3, color='red')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
inertias = []

# Creating 10 K-Mean models while varying the number of clusters (k)
for k in range(1,10):
    model = KMeans(n_clusters=k)
    
    # Fit model to samples
    model.fit(coefficients.iloc[:2, :].transpose())
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
plt.plot(range(1,10), inertias, '-p', color='blue')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.show()
# Out:
# C:\Users\Ubaid\miniconda3\envs\msc\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# %matplotlib inline
model = KMeans(n_clusters=3)
model.fit(coefficients.iloc[:2,:].transpose())

labels = model.predict(coefficients.iloc[:2,:].transpose())

# %%
plus_x = []
plus_y = []
x_x = []
x_y = []
star_x = []
star_y = []

for i in range(len(coefficients.iloc[0,:])):
    if labels[i] == 0:
        plus_x.append(coefficients.iloc[0, i])
        plus_y.append(coefficients.iloc[1, i])
    elif labels[i] == 1:
        x_x.append(coefficients.iloc[0, i])
        x_y.append(coefficients.iloc[1, i])
    else:
        star_x.append(coefficients.iloc[0, i])
        star_y.append(coefficients.iloc[1, i])

# %%
# %matplotlib inline
plt.scatter(plus_x, plus_y, c = 'red', marker = '+', label = 'K = 1')
plt.scatter(x_x, x_y, c = 'blue', marker = 'x', label = 'K = 2')
plt.scatter(star_x, star_y, c = 'gold', marker = '*', label = 'K = 3')
for i, txt in enumerate(np.array(df.columns)):
    plt.annotate(txt, (coefficients.iloc[0,:][i], coefficients.iloc[1,:][i]))
plt.legend()
plt.show()

# %%
def markermap(idx):
    markers = ['+', 'x', '*']
    return markers[idx]

list(map(markermap, labels))
# Out:
# ['+',
#  'x',
#  'x',
#  'x',
#  'x',
#  '+',
#  '*',
#  '+',
#  'x',
#  '+',
#  'x',
#  'x',
#  'x',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '*',
#  '+',
#  '*',
#  '+',
#  '+',
#  '+',
#  '+',
#  'x',
#  'x',
#  '+',
#  '+',
#  'x',
#  'x',
#  '+',
#  '+',
#  '*',
#  '*',
#  '*',
#  '*',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '*',
#  '+']

# %%
np.array(df.columns)
# Out:
# array(['Agric', 'Food ', 'Soda ', 'Beer ', 'Smoke', 'Toys ', 'Fun  ',
#        'Books', 'Hshld', 'Clths', 'Hlth ', 'MedEq', 'Drugs', 'Chems',
#        'Rubbr', 'Txtls', 'BldMt', 'Cnstr', 'Steel', 'FabPr', 'Mach ',
#        'ElcEq', 'Autos', 'Aero ', 'Ships', 'Guns ', 'Gold ', 'Mines',
#        'Coal ', 'Oil  ', 'Util ', 'Telcm', 'PerSv', 'BusSv', 'Comps',
#        'Chips', 'LabEq', 'Paper', 'Boxes', 'Trans', 'Whlsl', 'Rtail',
#        'Meals', 'Banks', 'Insur', 'RlEst', 'Fin  ', 'Other'], dtype=object)

# %%
model.get_params()
# Out:
# {'algorithm': 'auto',
#  'copy_x': True,
#  'init': 'k-means++',
#  'max_iter': 300,
#  'n_clusters': 3,
#  'n_init': 10,
#  'n_jobs': 'deprecated',
#  'precompute_distances': 'deprecated',
#  'random_state': None,
#  'tol': 0.0001,
#  'verbose': 0}
